# %%
import os
from simulation_linear import *
from dialog_component_real_data import *

# %%
people_num = 100
question_num = 100

# Where we save our checkpoints and graphs
experiment_dir = os.path.abspath("./experiments/")

# Create state tracker
state_tracker = StateTracker(people_num, question_num)

# Create estimators
q_estimator = LinearAgent(people_num, question_num)

# Run it!
episode_lengths, episode_rewards, episode_turn, episode_guess =  simulation_and_training(state_tracker,
                                                                    q_estimator=q_estimator,
                                                                    experiment_dir=experiment_dir,
                                                                    num_episodes=20000,
                                                                    epsilon_start=1.0,
                                                                    epsilon_end=0.1,
                                                                    epsilon_decay_steps=20000,
                                                                    discount_factor=0.99)
# Out:
# c:\users\v-zhifa\appdata\local\continuum\anaconda3\envs\tensorflow\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:84: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDRegressor'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# Step 5.0 (5) @ Episode 1/20000, result: -1.0
# Step 7.0 (143) @ Episode 11/20000, result: 1.0
# Step 2.0 (305) @ Episode 21/20000, result: -1.0
# Step 17.0 (493) @ Episode 31/20000, result: -1.0
# Step 21.0 (684) @ Episode 41/20000, result: 1.0
# Step 21.0 (866) @ Episode 51/20000, result: -1.0
# Step 21.0 (1052) @ Episode 61/20000, result: 1.0
# Step 21.0 (1223) @ Episode 71/20000, result: 1.0
# Step 21.0 (1420) @ Episode 81/20000, result: 1.0
# ...
